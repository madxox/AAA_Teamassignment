# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Prepare Weather data

# %%
df_weather = pd.read_csv("data/weather_data_2022.csv")

# %%
display(df_weather)
# Out:
#              Date      Time Temperature Dew Point Humidity  Wind Wind Speed  \
# 0      2022-01-01   6:15 PM        33°F      28°F     82°%   NNE     21°mph
# 1      2022-01-01   6:29 PM        32°F      27°F     82°%   NNE     22°mph
# 2      2022-01-01   6:53 PM        32°F      27°F     82°%   NNE     21°mph
# 3      2022-01-01   7:00 PM        32°F      28°F     85°%   NNE     22°mph
# 4      2022-01-01   7:10 PM        32°F      28°F     85°%   NNE     21°mph
# ...           ...       ...         ...       ...      ...   ...        ...
# 10189  2022-12-31   8:53 PM        37°F      30°F     76°%    SE      9°mph
# 10190  2022-12-31   9:53 PM        37°F      31°F     79°%    SE     10°mph
# 10191  2022-12-31  10:53 PM        37°F      32°F     82°%  CALM      0°mph
# 10192  2022-12-31  11:53 PM        37°F      32°F     82°%    SE      6°mph
# 10193  2022-12-31  12:53 AM        37°F      32°F     82°%   ESE      7°mph
#
#       Wind Gust  Pressure Precip.           Condition
# 0        31°mph  29.17°in  0.0°in  Light Snow / Windy
# 1        31°mph  29.17°in  0.0°in  Light Snow / Windy
# 2        33°mph  29.18°in  0.0°in  Light Snow / Windy
# 3        31°mph  29.18°in  0.0°in  Light Snow / Windy
# 4        29°mph  29.17°in  0.0°in  Light Snow / Windy
# ...         ...       ...     ...                 ...
# 10189    18°mph  29.23°in  0.0°in              Cloudy
# 10190     0°mph  29.21°in  0.0°in              Cloudy
# 10191     0°mph  29.22°in  0.0°in              Cloudy
# 10192     0°mph  29.22°in  0.0°in              Cloudy
# 10193     0°mph  29.19°in  0.0°in              Cloudy
#
# [10194 rows x 11 columns]

# %%
#create timestamp column and name it similar to the one of df_taxi in order to merge the two dataframes based on this column
df_weather['trip_start_timestamp'] = pd.to_datetime(df_weather['Date'] + ' ' + df_weather['Time'])

# %%
display(df_weather.dtypes)
# Out:
# Date                            object
# Time                            object
# Temperature                     object
# Dew Point                       object
# Humidity                        object
# Wind                            object
# Wind Speed                      object
# Wind Gust                       object
# Pressure                        object
# Precip.                         object
# Condition                       object
# trip_start_timestamp    datetime64[ns]
# dtype: object

# %%
df_weather = df_weather.sort_values('trip_start_timestamp')

# %% [markdown]
# Prepare Taxi data
#
# (include 'taxidata.csv' to data folder locally)

# %%
df_taxi = pd.read_csv("data/taxidata.csv")

# %%
display(df_taxi)
# Out:
#                                           trip_id  \
# 0        4404c6835b9e74e9f74d70f235200a8ce09db14a
# 1        466473fd2a196ebe92fb2983cb7e8af32e39aa1f
# 2        3f5cd3f78e5cab455606a31372a95d3204b2fb3f
# 3        38292159642750da7b20419330566f9eb0961cde
# 4        3e01498f8ff771ad7eb37e4844cef20201b6c339
# ...                                           ...
# 6382420  54d812a0b88f8f9707825261014b3563a0a60ace
# 6382421  7125b9e03a0f16c2dfb5eaf73ed057dc51eb68ef
# 6382422  52d1bd00d97eaed338bd98faf80c5709e22fef3d
# 6382423  0f0c856e620e6b4dfd2bb1e921d966dd179eeca1
# 6382424  50719da0933d6056acca25c91c253012288c70c6
#
#                                                    taxi_id  \
# 0        7e179f8ef66ae99ec2d1ec89224e0b7ee5469fe5627f6d...
# 1        d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...
# 2        847cf962bd6f62040673e6c24c24940aeb2d7fdaa54677...
# 3        81092e4881f56106fae845c3ae4492f8b3c3213c33c920...
# 4        4ae32e2eb244ce143800e0c40055e537cc50e3358a07ce...
# ...                                                    ...
# 6382420  f98ae5e71fdda8806710af321dce58002146886c013f41...
# 6382421  8eca35a570101ad24c638f1f43eecce9d0cb7843e13a75...
# 6382422  b5e2695a2f44b9bce7a0a86148ac418802f0067be1f6d4...
# 6382423  b21050ab3ad3d0972fd6378f6bf4d0251a8a7af42e6e0e...
# 6382424  d9293712880e8a69bed187b718a3f5ef512c5263984006...
#
#             trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0        2022-12-31T23:45:00.000  2023-01-01T00:15:00.000        2081.0
# 1        2022-12-31T23:45:00.000  2023-01-01T00:00:00.000         812.0
# 2        2022-12-31T23:45:00.000  2023-01-01T00:00:00.000         600.0
# 3        2022-12-31T23:45:00.000  2023-01-01T00:00:00.000         546.0
# 4        2022-12-31T23:45:00.000  2023-01-01T00:00:00.000         574.0
# ...                          ...                      ...           ...
# 6382420  2022-01-01T00:00:00.000  2022-01-01T00:00:00.000         536.0
# 6382421  2022-01-01T00:00:00.000  2022-01-01T00:15:00.000         897.0
# 6382422  2022-01-01T00:00:00.000  2022-01-01T00:00:00.000         598.0
# 6382423  2022-01-01T00:00:00.000  2022-01-01T00:00:00.000          33.0
# 6382424  2022-01-01T00:00:00.000  2022-01-01T00:00:00.000         501.0
#
#          trip_miles  pickup_census_tract  dropoff_census_tract  \
# 0              4.42                  NaN                   NaN
# 1              0.00                  NaN                   NaN
# 2              0.90                  NaN                   NaN
# 3              0.85                  NaN                   NaN
# 4              0.33                  NaN                   NaN
# ...             ...                  ...                   ...
# 6382420        4.83                  NaN                   NaN
# 6382421        2.07                  NaN                   NaN
# 6382422        6.64                  NaN                   NaN
# 6382423        0.17                  NaN                   NaN
# 6382424        0.65                  NaN                   NaN
#
#          pickup_community_area  dropoff_community_area  ...  extras  \
# 0                          2.0                     3.0  ...     0.0
# 1                          8.0                    24.0  ...     0.0
# 2                          8.0                     8.0  ...     3.0
# 3                          8.0                     8.0  ...     0.0
# 4                          8.0                     8.0  ...     0.0
# ...                        ...                     ...  ...     ...
# 6382420                   28.0                    22.0  ...     0.0
# 6382421                    8.0                    32.0  ...     1.5
# 6382422                    8.0                    77.0  ...     1.0
# 6382423                    3.0                     3.0  ...     0.0
# 6382424                    8.0                     8.0  ...     2.0
#
#          trip_total  payment_type                       company  \
# 0             20.50        Prcard                     Flash Cab
# 1             16.57        Mobile                     Flash Cab
# 2             12.00   Credit Card     Taxi Affiliation Services
# 3              6.50          Cash  Taxicab Insurance Agency Llc
# 4              6.25          Cash                  City Service
# ...             ...           ...                           ...
# 6382420       14.75          Cash                    Globe Taxi
# 6382421       11.25          Cash                      Sun Taxi
# 6382422       24.00   Credit Card                      Sun Taxi
# 6382423       63.27          Cash                     Flash Cab
# 6382424        8.25          Cash                      Sun Taxi
#
#          pickup_centroid_latitude pickup_centroid_longitude  \
# 0                       42.001571                -87.695013
# 1                       41.899602                -87.633308
# 2                       41.899602                -87.633308
# 3                       41.899602                -87.633308
# 4                       41.899602                -87.633308
# ...                           ...                       ...
# 6382420                 41.874005                -87.663518
# 6382421                 41.899602                -87.633308
# 6382422                 41.899602                -87.633308
# 6382423                 41.965812                -87.655879
# 6382424                 41.899602                -87.633308
#
#                     pickup_centroid_location  dropoff_centroid_latitude  \
# 0        POINT (-87.6950125892 42.001571027)                  41.965812
# 1        POINT (-87.6333080367 41.899602111)                  41.901207
# 2        POINT (-87.6333080367 41.899602111)                  41.899602
# 3        POINT (-87.6333080367 41.899602111)                  41.899602
# 4        POINT (-87.6333080367 41.899602111)                  41.899602
# ...                                      ...                        ...
# 6382420  POINT (-87.6635175498 41.874005383)                  41.922761
# 6382421  POINT (-87.6333080367 41.899602111)                  41.878866
# 6382422  POINT (-87.6333080367 41.899602111)                  41.986712
# 6382423   POINT (-87.6558787862 41.96581197)                  41.965812
# 6382424  POINT (-87.6333080367 41.899602111)                  41.899602
#
#          dropoff_centroid_longitude             dropoff_centroid_location
# 0                        -87.655879    POINT (-87.6558787862 41.96581197)
# 1                        -87.676356  POINT (-87.6763559892 41.9012069941)
# 2                        -87.633308   POINT (-87.6333080367 41.899602111)
# 3                        -87.633308   POINT (-87.6333080367 41.899602111)
# 4                        -87.633308   POINT (-87.6333080367 41.899602111)
# ...                             ...                                   ...
# 6382420                  -87.699155  POINT (-87.6991553432 41.9227606205)
# 6382421                  -87.625192  POINT (-87.6251921424 41.8788655841)
# 6382422                  -87.663416  POINT (-87.6634164054 41.9867117999)
# 6382423                  -87.655879    POINT (-87.6558787862 41.96581197)
# 6382424                  -87.633308   POINT (-87.6333080367 41.899602111)
#
# [6382425 rows x 23 columns]

# %%
df_taxi['trip_start_timestamp'] = pd.to_datetime(df_taxi['trip_start_timestamp'])

# %%
display(df_taxi.dtypes)
# Out:
# trip_id                               object
# taxi_id                               object
# trip_start_timestamp          datetime64[ns]
# trip_end_timestamp                    object
# trip_seconds                         float64
# trip_miles                           float64
# pickup_census_tract                  float64
# dropoff_census_tract                 float64
# pickup_community_area                float64
# dropoff_community_area               float64
# fare                                 float64
# tips                                 float64
# tolls                                float64
# extras                               float64
# trip_total                           float64
# payment_type                          object
# company                               object
# pickup_centroid_latitude             float64
# pickup_centroid_longitude            float64
# pickup_centroid_location              object
# dropoff_centroid_latitude            float64
# dropoff_centroid_longitude           float64
# dropoff_centroid_location             object
# dtype: object

# %%
df_taxi = df_taxi.sort_values('trip_start_timestamp')

# %% [markdown]
# Merge both data frames based on 'trip_start_timestamp'

# %%
df_merged = pd.merge_asof(df_taxi, df_weather, on='trip_start_timestamp', direction='nearest')

# %%
display(df_merged)
# Out:
#                                           trip_id  \
# 0        50719da0933d6056acca25c91c253012288c70c6
# 1        8385d429751b1a92b8dbf5c06d8c77dab3d6e3a9
# 2        7f7f6cf4d75843ded98e507bde2326ec4f6ddc44
# 3        7e157327f4d280b1b58a9310d58001f3a69617b1
# 4        79a27131be44dedb7fccb544771a1ac3cba41733
# ...                                           ...
# 6382420  111c2799be3ab7d09003316a28092a1f84d7d646
# 6382421  16fe903a7b322d63d70625e1604b80c2794e63e7
# 6382422  16af27a21bc6c4ca853275e5aa5707ef365dbe09
# 6382423  183df5a5898e25d8f00c5c2830e5b7f9902182f6
# 6382424  4404c6835b9e74e9f74d70f235200a8ce09db14a
#
#                                                    taxi_id  \
# 0        d9293712880e8a69bed187b718a3f5ef512c5263984006...
# 1        32f41dbfab64ed45d31d672512bf4528d078682d839f30...
# 2        d3068abc56994f67ba73bdbd3610e9baf804a34c6e9e5d...
# 3        94392ee820e83f72bebb76726fcf270ae473528a67189c...
# 4        368ce5511598af2cc07efdb68067d381174fdac1d47a28...
# ...                                                    ...
# 6382420  0bea3de3c36237d68b009b24ee3db86c78e9e618a73a3b...
# 6382421  2ace0a0c841190acb5513d4f011447a3e9df87da0cc213...
# 6382422  7e179f8ef66ae99ec2d1ec89224e0b7ee5469fe5627f6d...
# 6382423  ff5a3bcec871b7dd99b5eb851c17f4198eec9e3d4d1ece...
# 6382424  7e179f8ef66ae99ec2d1ec89224e0b7ee5469fe5627f6d...
#
#         trip_start_timestamp       trip_end_timestamp  trip_seconds  \
# 0        2022-01-01 00:00:00  2022-01-01T00:00:00.000         501.0
# 1        2022-01-01 00:00:00  2022-01-01T01:00:00.000        3046.0
# 2        2022-01-01 00:00:00  2022-01-01T00:15:00.000         356.0
# 3        2022-01-01 00:00:00  2022-01-01T00:15:00.000         427.0
# 4        2022-01-01 00:00:00  2022-01-01T00:00:00.000         293.0
# ...                      ...                      ...           ...
# 6382420  2022-12-31 23:45:00  2023-01-01T00:15:00.000        1380.0
# 6382421  2022-12-31 23:45:00  2023-01-01T00:00:00.000         763.0
# 6382422  2022-12-31 23:45:00  2023-01-01T00:15:00.000        2081.0
# 6382423  2022-12-31 23:45:00  2023-01-01T00:00:00.000         420.0
# 6382424  2022-12-31 23:45:00  2023-01-01T00:15:00.000        2081.0
#
#          trip_miles  pickup_census_tract  dropoff_census_tract  \
# 0              0.65                  NaN                   NaN
# 1             22.94                  NaN                   NaN
# 2              1.33         1.703108e+10          1.703124e+10
# 3              0.67         1.703108e+10          1.703108e+10
# 4              0.30                  NaN                   NaN
# ...             ...                  ...                   ...
# 6382420       12.00                  NaN                   NaN
# 6382421        2.10                  NaN                   NaN
# 6382422        4.42                  NaN                   NaN
# 6382423        1.00                  NaN                   NaN
# 6382424        4.42                  NaN                   NaN
#
#          pickup_community_area  dropoff_community_area  ...      Time  \
# 0                          8.0                     8.0  ...  12:13 AM
# 1                         32.0                     NaN  ...  12:13 AM
# 2                          8.0                    24.0  ...  12:13 AM
# 3                          8.0                     8.0  ...  12:13 AM
# 4                          NaN                     NaN  ...  12:13 AM
# ...                        ...                     ...  ...       ...
# 6382420                   56.0                    24.0  ...  11:53 PM
# 6382421                   28.0                     8.0  ...  11:53 PM
# 6382422                    2.0                     3.0  ...  11:53 PM
# 6382423                    8.0                     8.0  ...  11:53 PM
# 6382424                    2.0                     3.0  ...  11:53 PM
#
#          Temperature  Dew Point  Humidity  Wind Wind Speed Wind Gust  \
# 0               31°F       27°F      85°%    NE     21°mph    28°mph
# 1               31°F       27°F      85°%    NE     21°mph    28°mph
# 2               31°F       27°F      85°%    NE     21°mph    28°mph
# 3               31°F       27°F      85°%    NE     21°mph    28°mph
# 4               31°F       27°F      85°%    NE     21°mph    28°mph
# ...              ...        ...       ...   ...        ...       ...
# 6382420         37°F       32°F      82°%    SE      6°mph     0°mph
# 6382421         37°F       32°F      82°%    SE      6°mph     0°mph
# 6382422         37°F       32°F      82°%    SE      6°mph     0°mph
# 6382423         37°F       32°F      82°%    SE      6°mph     0°mph
# 6382424         37°F       32°F      82°%    SE      6°mph     0°mph
#
#          Pressure  Precip.           Condition
# 0        29.21°in   0.0°in  Light Snow / Windy
# 1        29.21°in   0.0°in  Light Snow / Windy
# 2        29.21°in   0.0°in  Light Snow / Windy
# 3        29.21°in   0.0°in  Light Snow / Windy
# 4        29.21°in   0.0°in  Light Snow / Windy
# ...           ...      ...                 ...
# 6382420  29.22°in   0.0°in              Cloudy
# 6382421  29.22°in   0.0°in              Cloudy
# 6382422  29.22°in   0.0°in              Cloudy
# 6382423  29.22°in   0.0°in              Cloudy
# 6382424  29.22°in   0.0°in              Cloudy
#
# [6382425 rows x 34 columns]
