# %%
import pandas as pd
import numpy as np

# %%
df_weather = pd.read_csv("data/weather_data_2022.csv")

# %%
display(df_weather.head())
# Out:
#          Date     Time Temperature Dew Point Humidity Wind Wind Speed  \
# 0  2022-01-01  6:15 PM        33°F      28°F     82°%  NNE     21°mph
# 1  2022-01-01  6:29 PM        32°F      27°F     82°%  NNE     22°mph
# 2  2022-01-01  6:53 PM        32°F      27°F     82°%  NNE     21°mph
# 3  2022-01-01  7:00 PM        32°F      28°F     85°%  NNE     22°mph
# 4  2022-01-01  7:10 PM        32°F      28°F     85°%  NNE     21°mph
#
#   Wind Gust  Pressure Precip.           Condition
# 0    31°mph  29.17°in  0.0°in  Light Snow / Windy
# 1    31°mph  29.17°in  0.0°in  Light Snow / Windy
# 2    33°mph  29.18°in  0.0°in  Light Snow / Windy
# 3    31°mph  29.18°in  0.0°in  Light Snow / Windy
# 4    29°mph  29.17°in  0.0°in  Light Snow / Windy

# %%
df_taxi = pd.read_csv("data/taxidata.csv")

# %%
display(df_taxi.head())
# Out:
#                                     trip_id  \
# 0  4404c6835b9e74e9f74d70f235200a8ce09db14a
# 1  466473fd2a196ebe92fb2983cb7e8af32e39aa1f
# 2  3f5cd3f78e5cab455606a31372a95d3204b2fb3f
# 3  38292159642750da7b20419330566f9eb0961cde
# 4  3e01498f8ff771ad7eb37e4844cef20201b6c339
#
#                                              taxi_id     trip_start_timestamp  \
# 0  7e179f8ef66ae99ec2d1ec89224e0b7ee5469fe5627f6d...  2022-12-31T23:45:00.000
# 1  d1d88b89ceb6d753007b6e795e3c24f4bea905a51e9d47...  2022-12-31T23:45:00.000
# 2  847cf962bd6f62040673e6c24c24940aeb2d7fdaa54677...  2022-12-31T23:45:00.000
# 3  81092e4881f56106fae845c3ae4492f8b3c3213c33c920...  2022-12-31T23:45:00.000
# 4  4ae32e2eb244ce143800e0c40055e537cc50e3358a07ce...  2022-12-31T23:45:00.000
#
#         trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2023-01-01T00:15:00.000        2081.0        4.42                  NaN
# 1  2023-01-01T00:00:00.000         812.0        0.00                  NaN
# ...

# %%
display(df_taxi.summary())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8972\993706800.py in ?()
# ----> 1 display(df_taxi.summary())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5571             and name not in self._accessors
#    5572             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'summary'
